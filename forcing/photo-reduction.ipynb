# %% [markdown]
# # Create photoreduction forcing files

# %%
import os
os.environ['PROJ_LIB'] = '/home/brogalla/anaconda3/share/proj'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.basemap import Basemap, cm
import cmocean
import netCDF4 as nc
import datetime as dt
import pickle

# %matplotlib notebook

# %%
imin, imax = 1480, 2180
jmin, jmax = 160, 800

# %%
mask  = nc.Dataset('/ocean/brogalla/GEOTRACES/ariane_runs/ANHA12_Ariane_mesh.nc')
tmask = np.array(mask.variables['tmask'])
cond = (tmask[0,:,:,:] > 0.1) 
land_mask = np.ma.masked_where(cond, tmask[0,:,:,:])

mesh  = nc.Dataset('/ocean/brogalla/GEOTRACES/data/ANHA12-EXH006_5d_gridT_y2002m01d05.nc')
lons  = np.array(mesh.variables['nav_lon'])
lats  = np.array(mesh.variables['nav_lat'])
tmask = tmask[0,:,imin:imax,jmin:jmax]

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[2,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('March')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[3,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('April')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[4,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('May')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[5,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('June')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[6,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('July')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[7,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('August')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[8,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('September')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[9,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('October')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[10,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('November')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax1, proj1 = pickle.load(open('/ocean/brogalla/GEOTRACES/analysis-brogalla/maps/mn-reference.pickle','rb'))

x, y = proj1(lons[1480:2180,160:800], lats[1480:2180,160:800])

CB1 = proj1.contourf(x, y, sol_flux[11,:,:], vmin=-200, vmax=200, cmap=cmocean.cm.balance)

ax1.set_title('December')

cbaxes = fig.add_axes([0.90, 0.14, 0.03, 0.65]) 
CBar = plt.colorbar(CB1, ax=ax1, cax=cbaxes)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# Parameterization for photo reduction:
# - Higher sol_flux means stronger photo reduction.
# - Background reduction value: 1
# - Photo-enhanced reduction value maximum: 58

# %%
norm_sol = np.abs((sol_flux - sol_flux.mean()))/sol_flux.max()

# %%
red_rate = norm_sol*58
red_rate[red_rate < 1] = 1

# %% [markdown]
# # Create forcing files

# %% [markdown]
# Read in monthly icemod files:

# %%
def load_variables(filename):
    a = nc.Dataset(filename)
    
    sol_flux = np.array(a.variables['iocesflx'][:,0,:,:])     
    
    return sol_flux

# %%
def red_rate_calc(year):
    sol_flux = load_variables('/data/brogalla/ANHA12/icemod_ave/ANHA12_EXH006_'+str(year)+'_monthly.nc')
    red_rate = (np.abs((sol_flux - sol_flux[:,1480:2180,160:800].mean()))/sol_flux[:,1480:2180,160:800].max())*58
    red_rate[red_rate < 1] = 1
    
    return red_rate

# %%
file_year=2018

# %%
red_rateyear = red_rate_calc(file_year)
# Out:
# (12, 2400, 1632)

# %%
print(np.amax(red_rateyear[:,1480:2180,160:800]), np.amin(red_rateyear[:,1480:2180,160:800]))
# Out:
# 56.125675 1.0

# %% [markdown]
# Save files

# %%
location='/data/brogalla/reduction_forcing/'

# %%
def save_file(filename, field1):
    ncd = nc.Dataset(filename, 'w', zlib=True)

    ncd.createDimension('x',len(mesh.dimensions['x']))
    ncd.createDimension('y',len(mesh.dimensions['y']))
    ncd.createDimension('time_counter',None)
    
    # variables
    red             = ncd.createVariable('kred', 'float64', ('y','x'))
    red.units       = 'Unitless'
    red.long_name   = 'Photoreduction multiplier'  
    red.coordinates = 'nav_lon nav_lat'
    red[:]          = field1[:]

    ncd.close()
    return

# %%
for i in range(1,13):
    if i < 10:
        save_file(location+'red_y'+str(file_year)+'m0'+str(i)+'.nc',red_rateyear[i-1,:,:])
    else:
        save_file(location+'red_y'+str(file_year)+'m'+str(i)+'.nc',red_rateyear[i-1,:,:])

# %%
file='red_y2002m09.nc'
ds = nc.Dataset(location+file)
reduction=np.array(ds.variables['kred'])

# %%
print(np.amax(reduction), np.amin(reduction), np.average(reduction))
# Out:
# 65.2651138305664 1.0 13.028272547897993
