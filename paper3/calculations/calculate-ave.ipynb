# %% [markdown]
# # Calculate monthly average

# %%
import numpy as np
import netCDF4 as nc
import xarray as xr
import pandas as pd 
import forcing.modules.mapping_functions as mf
import glob
from datetime import datetime
from calendar import monthrange
import time

# %matplotlib inline

# %% [markdown]
# #### Parameters:

# %%
# domain dimensions:
jmin, jmax = 159, 799
imin, imax = 1139, 2179
isize = imax-imin
jsize = jmax-jmin

days_in_month = [monthrange(2002,mth)[1] for mth in range(1,13)]

# %% [markdown]
# #### Files:

# %%
# Modified ANHA12 mesh mask file (http://knossos.eas.ualberta.ca/anha/anhatable.php)
mfile        = xr.open_dataset('/ocean/brogalla/GEOTRACES/data/ANHA12/ANHA12_mask_Pb-20220317.nc')
mesh_lon     = mfile['nav_lon'].values
mesh_lat     = mfile['nav_lat'].values
tmask        = mfile['tmask'].values[0,:,imin:imax,jmin:jmax]
bathy_masked = np.ma.masked_where((tmask> 0.1), tmask) 
mesh_depth   = mfile['nav_lev'].values
# mesh_bathy = np.array(mesh.variables['hdept'][0])

# %% [markdown]
# #### Functions

# %%
def write_to_file(votemper, vosaline, year, month):
    
    file_write = xr.Dataset(
        {'vosaline' : (("deptht","y","x"), vosaline),
         'votemper' : (("deptht","y","x"), votemper)}, 
        coords = {
            "time_counter": np.zeros(1),
            "deptht": mesh_depth,
            "y": np.zeros(mesh_lat.shape[0]),
            "x": np.zeros(mesh_lon.shape[1])},
    )
    
    file_write.to_netcdf(f'/data/brogalla/ANHA12/new_averages/gridT_{year}_{month:02}.nc', unlimited_dims='time_counter')
    
    return

# %%
def calculate_monthly_average(folder_ref, year, month):
    # Calculate monthly average:
    file_list = list(np.sort(glob.glob(f'{folder_ref}ANHA12-EXH006_5d_gridT_y{year}m{month:02}d??.nc')))
    max_day   = datetime.strptime(file_list[-1][45:56],'y%Ym%md%d').day

    # if the last file in the list does not contain the last day in the month, also load the first file of the next month
    if max_day < days_in_month[month-1]:
        files_next_month = np.sort(glob.glob(f'{folder_ref}ANHA12-EXH006_5d_gridT_y{year}m{month+1:02}d??.nc'))
        file_list.append(files_next_month[0])
        
    # read in each data file
    monthly_sum_T = 0; monthly_sum_S = 0;
    sum_days = 0
    for file in file_list:
        ds  = xr.open_dataset(f'{file}')
        sal  = ds['vosaline'].values[0,:,:,:]
        temp = ds['votemper'].values[0,:,:,:]
        
        date = datetime.strptime(file[45:56],'y%Ym%md%d')
#         print(date)
        
        if (date.day - 5 >= 0) & (date.day <= days_in_month[month-1]):
            monthly_sum_T += temp*(5) # since these are five-day files
            monthly_sum_S += sal *(5) 
            sum_days +=5
            print(f'Normal case: {date}, multiply by 5')
        elif (date.month == month) & (date.day - 5 < 0):
            monthly_sum_T += temp*(date.day)
            monthly_sum_S += sal *(date.day)
            sum_days += date.day
            print(f'Start of month: {date}, multiply by {date.day}')
        elif (date.month != month) & (date.day - 5 < 0):
            monthly_sum_T += temp*(days_in_month[month-1] - max_day)
            monthly_sum_S += sal *(days_in_month[month-1] - max_day)
            sum_days += (days_in_month[month-1] - max_day)
            print(f'End of month: {date}, multiply by {(days_in_month[month-1] - max_day)}')
        
    monthly_T_ave = monthly_sum_T / days_in_month[month-1]
    monthly_S_ave = monthly_sum_S / days_in_month[month-1]
   
    print(sum_days, days_in_month[month-1])

    write_to_file(monthly_T_ave, monthly_S_ave, year, month)
  
    return monthly_T_ave, monthly_S_ave

# %%
for month in range(1,13):
    T_ave_200401, S_ave_200401 = calculate_monthly_average('/data/brogalla/ANHA12/', 2021, month)
# Out:
# Normal case: 2021-01-05 00:00:00, multiply by 5
# Normal case: 2021-01-10 00:00:00, multiply by 5
# Normal case: 2021-01-15 00:00:00, multiply by 5
# Normal case: 2021-01-20 00:00:00, multiply by 5
# Normal case: 2021-01-25 00:00:00, multiply by 5
# Normal case: 2021-01-30 00:00:00, multiply by 5
# End of month: 2021-02-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2021-02-04 00:00:00, multiply by 4
# Normal case: 2021-02-09 00:00:00, multiply by 5
# Normal case: 2021-02-14 00:00:00, multiply by 5
# Normal case: 2021-02-19 00:00:00, multiply by 5
# Normal case: 2021-02-24 00:00:00, multiply by 5
# End of month: 2021-03-01 00:00:00, multiply by 4
# 28 28
# Start of month: 2021-03-01 00:00:00, multiply by 1
# Normal case: 2021-03-06 00:00:00, multiply by 5
# Normal case: 2021-03-11 00:00:00, multiply by 5
# Normal case: 2021-03-16 00:00:00, multiply by 5
# Normal case: 2021-03-21 00:00:00, multiply by 5
# Normal case: 2021-03-26 00:00:00, multiply by 5
# Normal case: 2021-03-31 00:00:00, multiply by 5
# 31 31
# Normal case: 2021-04-05 00:00:00, multiply by 5
# Normal case: 2021-04-10 00:00:00, multiply by 5
# Normal case: 2021-04-15 00:00:00, multiply by 5
# Normal case: 2021-04-20 00:00:00, multiply by 5
# Normal case: 2021-04-25 00:00:00, multiply by 5
# Normal case: 2021-04-30 00:00:00, multiply by 5
# 30 30
# Normal case: 2021-05-05 00:00:00, multiply by 5
# Normal case: 2021-05-10 00:00:00, multiply by 5
# Normal case: 2021-05-15 00:00:00, multiply by 5
# Normal case: 2021-05-20 00:00:00, multiply by 5
# Normal case: 2021-05-25 00:00:00, multiply by 5
# Normal case: 2021-05-30 00:00:00, multiply by 5
# End of month: 2021-06-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2021-06-04 00:00:00, multiply by 4
# Normal case: 2021-06-09 00:00:00, multiply by 5
# Normal case: 2021-06-14 00:00:00, multiply by 5
# Normal case: 2021-06-19 00:00:00, multiply by 5
# Normal case: 2021-06-24 00:00:00, multiply by 5
# Normal case: 2021-06-29 00:00:00, multiply by 5
# End of month: 2021-07-04 00:00:00, multiply by 1
# 30 30
# Start of month: 2021-07-04 00:00:00, multiply by 4
# Normal case: 2021-07-09 00:00:00, multiply by 5
# Normal case: 2021-07-14 00:00:00, multiply by 5
# Normal case: 2021-07-19 00:00:00, multiply by 5
# Normal case: 2021-07-24 00:00:00, multiply by 5
# Normal case: 2021-07-29 00:00:00, multiply by 5
# End of month: 2021-08-03 00:00:00, multiply by 2
# 31 31
# Start of month: 2021-08-03 00:00:00, multiply by 3
# Normal case: 2021-08-08 00:00:00, multiply by 5
# Normal case: 2021-08-13 00:00:00, multiply by 5
# Normal case: 2021-08-18 00:00:00, multiply by 5
# Normal case: 2021-08-23 00:00:00, multiply by 5
# Normal case: 2021-08-28 00:00:00, multiply by 5
# End of month: 2021-09-02 00:00:00, multiply by 3
# 31 31
# Start of month: 2021-09-02 00:00:00, multiply by 2
# Normal case: 2021-09-07 00:00:00, multiply by 5
# Normal case: 2021-09-12 00:00:00, multiply by 5
# Normal case: 2021-09-17 00:00:00, multiply by 5
# Normal case: 2021-09-22 00:00:00, multiply by 5
# Normal case: 2021-09-27 00:00:00, multiply by 5
# End of month: 2021-10-02 00:00:00, multiply by 3
# 30 30
# Start of month: 2021-10-02 00:00:00, multiply by 2
# Normal case: 2021-10-07 00:00:00, multiply by 5
# Normal case: 2021-10-12 00:00:00, multiply by 5
# Normal case: 2021-10-17 00:00:00, multiply by 5
# Normal case: 2021-10-22 00:00:00, multiply by 5
# Normal case: 2021-10-27 00:00:00, multiply by 5
# End of month: 2021-11-01 00:00:00, multiply by 4
# 31 31
# Start of month: 2021-11-01 00:00:00, multiply by 1
# Normal case: 2021-11-06 00:00:00, multiply by 5
# Normal case: 2021-11-11 00:00:00, multiply by 5
# Normal case: 2021-11-16 00:00:00, multiply by 5
# Normal case: 2021-11-21 00:00:00, multiply by 5
# Normal case: 2021-11-26 00:00:00, multiply by 5
# End of month: 2021-12-01 00:00:00, multiply by 4
# 30 30
# Start of month: 2021-12-01 00:00:00, multiply by 1
# Normal case: 2021-12-06 00:00:00, multiply by 5
# Normal case: 2021-12-11 00:00:00, multiply by 5
# Normal case: 2021-12-16 00:00:00, multiply by 5
# Normal case: 2021-12-21 00:00:00, multiply by 5
# Normal case: 2021-12-26 00:00:00, multiply by 5
# Normal case: 2021-12-31 00:00:00, multiply by 5
# 31 31

# %% [markdown]
# #### Mn extended domain run:

# %%
def write_Mn_to_file(Mn, year, month):
    
    file_write = xr.Dataset(
        {'oxidismn' : (("deptht","y","x"), Mn)}, 
        coords = {
            "time_counter": np.zeros(1),
            "deptht": mesh_depth,
            "y": np.zeros(mesh_lat[imin:imax,jmin:jmax].shape[0]),
            "x": np.zeros(mesh_lon[imin:imax,jmin:jmax].shape[1])},
    )
    
    file_write.to_netcdf(f'/data/brogalla/run_storage/Mn-extended-domain-202210/oMn_y{year}m{month:02}.nc', unlimited_dims='time_counter')
    
    return

# %%
def calculate_monthly_oMn_average(folder_ref, year, month):
    # Calculate monthly average: 
    file_list = list(np.sort(glob.glob(f'{folder_ref}'+\
                                       f'ANHA12_EXH006_5d_{year}0101_{year}1231_ptrc_T_{year}????-{year}{month:02}??.nc')))
    max_day   = datetime.strptime(file_list[-1][130:138],'%Y%m%d').day

    # if the last file in the list does not contain the last day in the month, also load the first file of the next month
    if max_day < days_in_month[month-1]:
        files_next_month = np.sort(glob.glob(f'{folder_ref}'+\
                                             f'ANHA12_EXH006_5d_{year}0101_{year}1231_ptrc_T_{year}{month:02}??-{year}{month+1:02}??.nc'))
        file_list.append(files_next_month[0])
        
    # read in each data file
    monthly_sum_oMn = 0;
    sum_days = 0
    for file in file_list:
        ds   = xr.open_dataset(f'{file}')
        omn  = ds['oxidismn'].values[0,:,:,:]
        
        date = datetime.strptime(file[130:138],'%Y%m%d')
        if (date.day - 5 >= 0) & (date.day <= days_in_month[month-1]):
            monthly_sum_oMn += omn*(5) # since these are five-day files
            sum_days +=5
            print(f'Normal case: {date}, multiply by 5')
        elif (date.month == month) & (date.day - 5 < 0):
            monthly_sum_oMn += omn*(date.day)
            sum_days += date.day
            print(f'Start of month: {date}, multiply by {date.day}')
        elif (date.month != month) & (date.day - 5 < 0):
            monthly_sum_oMn += omn*(days_in_month[month-1] - max_day)
            sum_days += (days_in_month[month-1] - max_day)
            print(f'End of month: {date}, multiply by {(days_in_month[month-1] - max_day)}')
        
    monthly_oMn_ave = monthly_sum_oMn / days_in_month[month-1]
   
    print(sum_days, days_in_month[month-1])

    write_Mn_to_file(monthly_oMn_ave, year, month)
  
    return monthly_oMn_ave

# %%
for year in range(2018,2021):
    for month in range(1,13):
        oMn_ave = calculate_monthly_oMn_average(f'/data/brogalla/run_storage/Mn-extended-domain-202210/Mn-extended-{year}-20220927/', \
                                                year, month)
# Out:
# Normal case: 2018-01-05 00:00:00, multiply by 5
# Normal case: 2018-01-10 00:00:00, multiply by 5
# Normal case: 2018-01-15 00:00:00, multiply by 5
# Normal case: 2018-01-20 00:00:00, multiply by 5
# Normal case: 2018-01-25 00:00:00, multiply by 5
# Normal case: 2018-01-30 00:00:00, multiply by 5
# End of month: 2018-02-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2018-02-04 00:00:00, multiply by 4
# Normal case: 2018-02-09 00:00:00, multiply by 5
# Normal case: 2018-02-14 00:00:00, multiply by 5
# Normal case: 2018-02-19 00:00:00, multiply by 5
# Normal case: 2018-02-24 00:00:00, multiply by 5
# End of month: 2018-03-01 00:00:00, multiply by 4
# 28 28
# Start of month: 2018-03-01 00:00:00, multiply by 1
# Normal case: 2018-03-06 00:00:00, multiply by 5
# Normal case: 2018-03-11 00:00:00, multiply by 5
# Normal case: 2018-03-16 00:00:00, multiply by 5
# Normal case: 2018-03-21 00:00:00, multiply by 5
# Normal case: 2018-03-26 00:00:00, multiply by 5
# Normal case: 2018-03-31 00:00:00, multiply by 5
# 31 31
# Normal case: 2018-04-05 00:00:00, multiply by 5
# Normal case: 2018-04-10 00:00:00, multiply by 5
# Normal case: 2018-04-15 00:00:00, multiply by 5
# Normal case: 2018-04-20 00:00:00, multiply by 5
# Normal case: 2018-04-25 00:00:00, multiply by 5
# Normal case: 2018-04-30 00:00:00, multiply by 5
# 30 30
# Normal case: 2018-05-05 00:00:00, multiply by 5
# Normal case: 2018-05-10 00:00:00, multiply by 5
# Normal case: 2018-05-15 00:00:00, multiply by 5
# Normal case: 2018-05-20 00:00:00, multiply by 5
# Normal case: 2018-05-25 00:00:00, multiply by 5
# Normal case: 2018-05-30 00:00:00, multiply by 5
# End of month: 2018-06-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2018-06-04 00:00:00, multiply by 4
# Normal case: 2018-06-09 00:00:00, multiply by 5
# Normal case: 2018-06-14 00:00:00, multiply by 5
# Normal case: 2018-06-19 00:00:00, multiply by 5
# Normal case: 2018-06-24 00:00:00, multiply by 5
# Normal case: 2018-06-29 00:00:00, multiply by 5
# End of month: 2018-07-04 00:00:00, multiply by 1
# 30 30
# Start of month: 2018-07-04 00:00:00, multiply by 4
# Normal case: 2018-07-09 00:00:00, multiply by 5
# Normal case: 2018-07-14 00:00:00, multiply by 5
# Normal case: 2018-07-19 00:00:00, multiply by 5
# Normal case: 2018-07-24 00:00:00, multiply by 5
# Normal case: 2018-07-29 00:00:00, multiply by 5
# End of month: 2018-08-03 00:00:00, multiply by 2
# 31 31
# Start of month: 2018-08-03 00:00:00, multiply by 3
# Normal case: 2018-08-08 00:00:00, multiply by 5
# Normal case: 2018-08-13 00:00:00, multiply by 5
# Normal case: 2018-08-18 00:00:00, multiply by 5
# Normal case: 2018-08-23 00:00:00, multiply by 5
# Normal case: 2018-08-28 00:00:00, multiply by 5
# End of month: 2018-09-02 00:00:00, multiply by 3
# 31 31
# Start of month: 2018-09-02 00:00:00, multiply by 2
# Normal case: 2018-09-07 00:00:00, multiply by 5
# Normal case: 2018-09-12 00:00:00, multiply by 5
# Normal case: 2018-09-17 00:00:00, multiply by 5
# Normal case: 2018-09-22 00:00:00, multiply by 5
# Normal case: 2018-09-27 00:00:00, multiply by 5
# End of month: 2018-10-02 00:00:00, multiply by 3
# 30 30
# Start of month: 2018-10-02 00:00:00, multiply by 2
# Normal case: 2018-10-07 00:00:00, multiply by 5
# Normal case: 2018-10-12 00:00:00, multiply by 5
# Normal case: 2018-10-17 00:00:00, multiply by 5
# Normal case: 2018-10-22 00:00:00, multiply by 5
# Normal case: 2018-10-27 00:00:00, multiply by 5
# End of month: 2018-11-01 00:00:00, multiply by 4
# 31 31
# Start of month: 2018-11-01 00:00:00, multiply by 1
# Normal case: 2018-11-06 00:00:00, multiply by 5
# Normal case: 2018-11-11 00:00:00, multiply by 5
# Normal case: 2018-11-16 00:00:00, multiply by 5
# Normal case: 2018-11-21 00:00:00, multiply by 5
# Normal case: 2018-11-26 00:00:00, multiply by 5
# End of month: 2018-12-01 00:00:00, multiply by 4
# 30 30
# Start of month: 2018-12-01 00:00:00, multiply by 1
# Normal case: 2018-12-06 00:00:00, multiply by 5
# Normal case: 2018-12-11 00:00:00, multiply by 5
# Normal case: 2018-12-16 00:00:00, multiply by 5
# Normal case: 2018-12-21 00:00:00, multiply by 5
# Normal case: 2018-12-26 00:00:00, multiply by 5
# Normal case: 2018-12-31 00:00:00, multiply by 5
# 31 31
# Normal case: 2019-01-05 00:00:00, multiply by 5
# Normal case: 2019-01-10 00:00:00, multiply by 5
# Normal case: 2019-01-15 00:00:00, multiply by 5
# Normal case: 2019-01-20 00:00:00, multiply by 5
# Normal case: 2019-01-25 00:00:00, multiply by 5
# Normal case: 2019-01-30 00:00:00, multiply by 5
# End of month: 2019-02-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2019-02-04 00:00:00, multiply by 4
# Normal case: 2019-02-09 00:00:00, multiply by 5
# Normal case: 2019-02-14 00:00:00, multiply by 5
# Normal case: 2019-02-19 00:00:00, multiply by 5
# Normal case: 2019-02-24 00:00:00, multiply by 5
# End of month: 2019-03-01 00:00:00, multiply by 4
# 28 28
# Start of month: 2019-03-01 00:00:00, multiply by 1
# Normal case: 2019-03-06 00:00:00, multiply by 5
# Normal case: 2019-03-11 00:00:00, multiply by 5
# Normal case: 2019-03-16 00:00:00, multiply by 5
# Normal case: 2019-03-21 00:00:00, multiply by 5
# Normal case: 2019-03-26 00:00:00, multiply by 5
# Normal case: 2019-03-31 00:00:00, multiply by 5
# 31 31
# Normal case: 2019-04-05 00:00:00, multiply by 5
# Normal case: 2019-04-10 00:00:00, multiply by 5
# Normal case: 2019-04-15 00:00:00, multiply by 5
# Normal case: 2019-04-20 00:00:00, multiply by 5
# Normal case: 2019-04-25 00:00:00, multiply by 5
# Normal case: 2019-04-30 00:00:00, multiply by 5
# 30 30
# Normal case: 2019-05-05 00:00:00, multiply by 5
# Normal case: 2019-05-10 00:00:00, multiply by 5
# Normal case: 2019-05-15 00:00:00, multiply by 5
# Normal case: 2019-05-20 00:00:00, multiply by 5
# Normal case: 2019-05-25 00:00:00, multiply by 5
# Normal case: 2019-05-30 00:00:00, multiply by 5
# End of month: 2019-06-04 00:00:00, multiply by 1
# 31 31
# Start of month: 2019-06-04 00:00:00, multiply by 4
# Normal case: 2019-06-09 00:00:00, multiply by 5
# Normal case: 2019-06-14 00:00:00, multiply by 5
# Normal case: 2019-06-19 00:00:00, multiply by 5
# Normal case: 2019-06-24 00:00:00, multiply by 5
# Normal case: 2019-06-29 00:00:00, multiply by 5
# End of month: 2019-07-04 00:00:00, multiply by 1
# 30 30
# Start of month: 2019-07-04 00:00:00, multiply by 4
# Normal case: 2019-07-09 00:00:00, multiply by 5
# Normal case: 2019-07-14 00:00:00, multiply by 5
# Normal case: 2019-07-19 00:00:00, multiply by 5
# Normal case: 2019-07-24 00:00:00, multiply by 5
# Normal case: 2019-07-29 00:00:00, multiply by 5
# End of month: 2019-08-03 00:00:00, multiply by 2
# 31 31
# Start of month: 2019-08-03 00:00:00, multiply by 3
# Normal case: 2019-08-08 00:00:00, multiply by 5
# Normal case: 2019-08-13 00:00:00, multiply by 5
# Normal case: 2019-08-18 00:00:00, multiply by 5
# Normal case: 2019-08-23 00:00:00, multiply by 5
# Normal case: 2019-08-28 00:00:00, multiply by 5
# End of month: 2019-09-02 00:00:00, multiply by 3
# 31 31
# Start of month: 2019-09-02 00:00:00, multiply by 2
# Normal case: 2019-09-07 00:00:00, multiply by 5
# Normal case: 2019-09-12 00:00:00, multiply by 5
# Normal case: 2019-09-17 00:00:00, multiply by 5
# Normal case: 2019-09-22 00:00:00, multiply by 5
# Normal case: 2019-09-27 00:00:00, multiply by 5
# End of month: 2019-10-02 00:00:00, multiply by 3
# 30 30
# Start of month: 2019-10-02 00:00:00, multiply by 2
# Normal case: 2019-10-07 00:00:00, multiply by 5
# Normal case: 2019-10-12 00:00:00, multiply by 5
# Normal case: 2019-10-17 00:00:00, multiply by 5
# Normal case: 2019-10-22 00:00:00, multiply by 5
# Normal case: 2019-10-27 00:00:00, multiply by 5
# End of month: 2019-11-01 00:00:00, multiply by 4
# 31 31
# Start of month: 2019-11-01 00:00:00, multiply by 1
# Normal case: 2019-11-06 00:00:00, multiply by 5
# Normal case: 2019-11-11 00:00:00, multiply by 5
# Normal case: 2019-11-16 00:00:00, multiply by 5
# Normal case: 2019-11-21 00:00:00, multiply by 5
# Normal case: 2019-11-26 00:00:00, multiply by 5
# End of month: 2019-12-01 00:00:00, multiply by 4
# 30 30
# Start of month: 2019-12-01 00:00:00, multiply by 1
# Normal case: 2019-12-06 00:00:00, multiply by 5
# Normal case: 2019-12-11 00:00:00, multiply by 5
# Normal case: 2019-12-16 00:00:00, multiply by 5
# Normal case: 2019-12-21 00:00:00, multiply by 5
# Normal case: 2019-12-26 00:00:00, multiply by 5
# Normal case: 2019-12-31 00:00:00, multiply by 5
# 31 31
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-4df7ca1411cc> in <module>
#       2     for month in range(1,13):
#       3         oMn_ave = calculate_monthly_oMn_average(f'/data/brogalla/run_storage/Mn-extended-domain-202210/Mn-extended-{year}-20220927/', \
# ----> 4                                                 year, month)
#
# <ipython-input-20-6fbeb21caf54> in calculate_monthly_oMn_average(folder_ref, year, month)
#       3     file_list = list(np.sort(glob.glob(f'{folder_ref}'+\
#       4                                        f'ANHA12_EXH006_5d_{year}0101_{year}1231_ptrc_T_{year}????-{year}{month:02}??.nc')))
# ----> 5     max_day   = datetime.strptime(file_list[-1][130:138],'%Y%m%d').day
#       6
#       7     # if the last file in the list does not contain the last day in the month, also load the first file of the next month
#
# IndexError: list index out of range

# %% [markdown]
# #### Phosphate biomass from BLING:

# %%
def write_biomass_to_file(biomass, fpop, jp_pop, year, month):
    
    file_write = xr.Dataset(
        {'biomass_p' : (("deptht","y","x"), biomass),
         'fpop' : (("deptht","y","x"), fpop),
         'jp_pop' : (("deptht","y","x"), jp_pop)}, 
        coords = {
            "time_counter": np.zeros(1),
            "deptht": mesh_depth,
            "y": np.zeros(800),
            "x": np.zeros(544)},
    )
    
    file_write.to_netcdf(f'/data/brogalla/ANHA4/BLING-EPM101/ANHA4-EPM101_y{year}m{month:02}.nc', unlimited_dims='time_counter')
    
    return

# %%
# Similar function but for BLING:
# folder = '/ocean/brogalla/GEOTRACES/BLING-EMP101/'
# file = 'ANHA4-EPM101_y2002m01d05_gridB.nc'

def calculate_monthly_biomass_average(folder_ref, year, month):
    # Calculate monthly average:
    file_list = list(np.sort(glob.glob(f'{folder_ref}ANHA4-EPM101_y{year}m{month:02}d??_gridB.nc')))
    max_day   = datetime.strptime(file_list[-1][52:63],'y%Ym%md%d').day

    # if the last file in the list does not contain the last day in the month, also load the first file of the next month
    if max_day < days_in_month[month-1]:
        files_next_month = np.sort(glob.glob(f'{folder_ref}ANHA4-EPM101_y{year}m{month+1:02}d??_gridB.nc'))
        file_list.append(files_next_month[0])
        
    # read in each data file
    monthly_sum_biomass = 0; monthly_sum_jppop = 0; monthly_sum_fpop = 0;
    sum_days = 0
    for file in file_list:
        ds      = xr.open_dataset(f'{file}')
        biomass = ds['biomass_p'].values[0,:,:,:]
        jp_pop  = ds['jp_pop'].values[0,:,:,:]
        fpop    = ds['fpop'].values[0,:,:,:]
        
        date    = datetime.strptime(file[52:63],'y%Ym%md%d')
        
        if (date.day - 5 >= 0) & (date.day <= days_in_month[month-1]):
            monthly_sum_biomass += biomass*(5) # since these are five-day files
            monthly_sum_jppop   += jp_pop*(5) # since these are five-day files
            monthly_sum_fpop    += fpop*(5) # since these are five-day files
            sum_days +=5
            print(f'Normal case: {date}, multiply by 5')
        elif (date.month == month) & (date.day - 5 < 0):
            monthly_sum_biomass += biomass*(date.day)
            monthly_sum_jppop   += jp_pop*(date.day)
            monthly_sum_fpop    += fpop*(date.day)
            sum_days += date.day
            print(f'Start of month: {date}, multiply by {date.day}')
        elif (date.month != month) & (date.day - 5 < 0):
            monthly_sum_biomass += biomass*(days_in_month[month-1] - max_day)
            monthly_sum_jppop   += jp_pop*(days_in_month[month-1] - max_day)
            monthly_sum_fpop    += fpop*(days_in_month[month-1] - max_day)
            sum_days += (days_in_month[month-1] - max_day)
            print(f'End of month: {date}, multiply by {(days_in_month[month-1] - max_day)}')
        
    monthly_biomass_ave = monthly_sum_biomass / days_in_month[month-1]
    monthly_jppop_ave   = monthly_sum_jppop   / days_in_month[month-1]
    monthly_fpop_ave    = monthly_sum_fpop    / days_in_month[month-1]
   
    print(sum_days, days_in_month[month-1])

    write_biomass_to_file(monthly_biomass_ave, monthly_jppop_ave, monthly_fpop_ave, year, month)
  
    return monthly_biomass_ave

# %%
for year in range(2019,2020):
    for month in range(1,13):
        bio_ave_200201 = calculate_monthly_biomass_average('/ocean/brogalla/GEOTRACES/BLING-EPM101/', year, month)
