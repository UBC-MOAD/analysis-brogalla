# %% [markdown]
# # Create monthly CESM atmospheric deposition files
#
# NCAR CESM output:
# Community Earth System Model (Community Atmosphere Model - CAM https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1002/2013MS000279) output: https://www.earthsystemgrid.org/; CESM1 CAM5 BGC Large Ensemble Atmosphere Post Processed Data, Monthly Averages.
#
# Specific run output: https://www.earthsystemgrid.org/dataset/ucar.cgd.ccsm4.CESM_CAM5_BGC_LE.atm.proc.monthly_ave.html

# %%
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
import datetime
from mpl_toolkits.basemap import Basemap, cm
import cmocean
import matplotlib
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
print('Run id: ucar.cgd.ccsm4.CESM_CAM5_BGC_LE')
# Out:
# Run id: ucar.cgd.ccsm4.CESM_CAM5_BGC_LE

# %% [markdown]
# For Mode MAM3 (https://www.geosci-model-dev.net/5/709/2012/):
#
# - a1 --- Aitken mode --- 0.015-0.053 μm
# - a2 --- Accumulation mode --- 0.058-0.27 μm
# - a3 --- Coarse mode --- 0.80-3.65 μm

# %% [markdown]
# ##### Load files

# %%
mask  = nc.Dataset('/ocean/brogalla/GEOTRACES/ariane_runs/ANHA12_Ariane_mesh.nc')
tmask = np.array(mask.variables['tmask'])
tmask = np.array(tmask[0,:,:,:])

mesh  = nc.Dataset('/data/brogalla/old/meshmasks/ANHA12_mesh1.nc')
mlons = np.array(mesh.variables['nav_lon'])
mlats = np.array(mesh.variables['nav_lat'])
mlons = np.array(mlons)
mlats = np.array(mlats)

cond = (tmask > 0.1) 
Z_masked = np.ma.masked_where(cond, tmask)

# %% [markdown]
# ##### Functions

# %%
def interp_np(nav_lon, nav_lat, var_in, lon_ANHA12, lat_ANHA12):
    ''' Interpolate some field to ANHA12 grid.
        The function is based on the bilinear interpolation in scipy, griddata 
        =======================================================================
            nav_lon, nav_lat        : input field lon/lat
            lon_ANHA12, lat_ANHA12  : ANHA12 defined lons/lats
            var_in                  : 2-D model variable
    '''
    from scipy.interpolate import griddata
    LatLonPair = (nav_lon.flatten(), nav_lat.flatten())
    a = nav_lon.flatten()
    b = nav_lat.flatten()
    c = var_in.flatten()
#     print(a.shape, b.shape, c.shape, lon_ANHA12.shape, lat_ANHA12.shape)
    var_out = griddata(LatLonPair, var_in.flatten(), (lon_ANHA12, lat_ANHA12), method='linear')
    # Take nearest neighbour interpolation to fill nans
    var_fill = griddata(LatLonPair, var_in.flatten(), (lon_ANHA12, lat_ANHA12), method='nearest')
    
    var_out[np.isnan(var_out)] = var_fill[np.isnan(var_out)]
    return var_out

# %%
def save_file(filename, field1, field2, field3):
    ncd = nc.Dataset(filename, 'w', zlib=True)
#     nc_tools.init_dataset_attrs(
#         ncd,
#         title='dust input field',
#         notebook_name='',
#         nc_filepath='./monthly_CESM_forcing.nc',
#         comment='CESM ucar.cgd.ccsm4.CESM_CAM5_BGC_LE dust deposition field')

    ncd.createDimension('x',len(mesh.dimensions['x']))
    ncd.createDimension('y',len(mesh.dimensions['y']))
    ncd.createDimension('time_counter',None)
    
    # variables
    fine_dust             = ncd.createVariable('fdust', 'float64', ('y','x'))
    fine_dust.units       = 'kg/m2/s'
    fine_dust.long_name   = 'Fine dust deposition flux'  
    fine_dust.coordinates = 'nav_lon nav_lat'
    fine_dust[:]          = field1
    
    coarse_dust             = ncd.createVariable('cdust', 'float64', ('y','x'))
    coarse_dust.units       = 'kg/m2/s'
    coarse_dust.long_name   = 'Coarse dust deposition flux'  
    coarse_dust.coordinates = 'nav_lon nav_lat'
    coarse_dust[:]          = field2
    
    black_c             = ncd.createVariable('bc', 'float64', ('y','x'))
    black_c.units       = 'kg/m2/s'
    black_c.long_name   = 'Black carbon deposition flux'  
    black_c.coordinates = 'nav_lon nav_lat'
    black_c[:]          = field3
    
    print('saved ', filename)

    ncd.close()
    return

# %%
def load_data():
    folder = '/ocean/brogalla/GEOTRACES/data/NCAR/'

    dst_a1D = nc.Dataset(folder+'merged_dst_a1DDF.nc')
    dst_a1S = nc.Dataset(folder+'merged_dst_a1SFWET.nc')
    dst_a3D = nc.Dataset(folder+'merged_dst_a3DDF.nc')
    dst_a3S = nc.Dataset(folder+'merged_dst_a3SFWET.nc')
    bc_a1D  = nc.Dataset(folder+'merged_bc_a1DDF.nc')
    bc_a1S  = nc.Dataset(folder+'merged_bc_a1SFWET.nc')
    
    dst_a1DDF   = np.array(dst_a1D.variables['dst_a1DDF'])
    dst_a1SFWET = np.array(dst_a1S.variables['dst_a1SFWET'])
    dst_a3DDF   = np.array(dst_a3D.variables['dst_a3DDF'])
    dst_a3SFWET = np.array(dst_a3S.variables['dst_a3SFWET'])
    BC_a1DDF    = np.array(bc_a1D.variables['bc_a1DDF'])
    BC_a1SFWET  = np.array(bc_a1S.variables['bc_a1SFWET'])
    
    # zero negative deposition fluxes:
    dst_a1DDF[dst_a1DDF < 0] = 0
    dst_a1SFWET[dst_a1SFWET < 0] = 0
    dst_a3DDF[dst_a3DDF < 0] = 0
    dst_a3SFWET[dst_a3SFWET < 0] = 0
    BC_a1DDF[BC_a1DDF < 0] = 0
    BC_a1SFWET[BC_a1SFWET < 0] = 0
    
    lon  = dst_a1D.variables['lon']
    lat  = dst_a1D.variables['lat']
    date = dst_a1D.variables['date']
    
    lon = np.array(lon)
    for i in range(0,len(lon)):
        if lon[i] >= 180:
            lon[i] = -360+lon[i]
            
    # change lons and lats array dimensions: (192x288)
    lons, lats = np.meshgrid(lon,lat)
    lons=np.array(lons)
    lats=np.array(lats)    
    
    dst_a1 = np.add(dst_a1DDF[:,:,:], dst_a1SFWET[:,:,:])
    dst_a3 = np.add(dst_a3DDF[:,:,:], dst_a3SFWET[:,:,:])
    bc_a1 = np.add(BC_a1DDF[:,:,:], BC_a1SFWET[:,:,:])
    
    return date, lons, lats, dst_a1, dst_a3, bc_a1

# %%
def find_dates(file_year):
    file_date_start = file_year*10000 + 101
    file_date_end = file_year*10000 + 1201
    
    start_index = []
    end_index = []

    for i in range(0,len(date)):
        if date[i] == file_date_start:
            start_index = i
        elif date[i] == file_date_end:
            end_index = i

    # print('start index: ', start_index)
    # print('end index: ', end_index)
    
    return start_index, end_index

# %%
def data_to_ANHA12(file_year, savefiles=False):
    
    si, ei = find_dates(file_year)
    dusta1 = dust_a1[si:ei+1,:,:]
    dusta3 = dust_a3[si:ei+1,:,:]
    bca1   = bc_a1[si:ei+1,:,:]
    print('Check that output is of the correct dimensions: ', dusta1.shape, dusta3.shape, bca1.shape)
    
    interp_dst_a1 = np.empty((12, 2400, 1632))
    interp_dst_a3 = np.empty((12, 2400, 1632))
    interp_bc_a1  = np.empty((12, 2400, 1632))

    # loop over the months:
    for i in range(0,12):
        interp_dst_a1[i,:,:] = interp_np(lons, lats, dusta1[i,:,:], mlons, mlats)
        interp_dst_a3[i,:,:] = interp_np(lons, lats, dusta3[i,:,:], mlons, mlats)
        interp_bc_a1[i,:,:]  = interp_np(lons, lats, bca1[i,:,:], mlons, mlats)
        
    if savefiles:
        location = '/ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/'
        
        for i in range(1,13):
            if i < 10:
                save_file(location+'atm_flux_y'+str(file_year)+'m0'+str(i)+'.nc',interp_dst_a1[i-1,:,:],\
                          interp_dst_a3[i-1,:,:], interp_bc_a1[i-1,:,:])
            else:
                save_file(location+'atm_flux_y'+str(file_year)+'m'+str(i)+'.nc',interp_dst_a1[i-1,:,:],\
                          interp_dst_a3[i-1,:,:], interp_bc_a1[i-1,:,:])    
    
    return interp_dst_a1, interp_dst_a3, interp_bc_a1

# %% [markdown]
# Interpolate to ANHA12 grid:

# %%
date, lons, lats, dust_a1, dust_a3, bc_a1 = load_data()

# %%
for year in np.arange(2007,2020,1):
    print(year)
    interp_dst_a1, interp_dst_a3, interp_bc_a1 = data_to_ANHA12(year, savefiles=True)
# Out:
# 2007
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2007m12.nc
# 2008
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2008m12.nc
# 2009
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2009m12.nc
# 2010
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2010m12.nc
# 2011
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2011m12.nc
# 2012
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2012m12.nc
# 2013
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2013m12.nc
# 2014
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2014m12.nc
# 2015
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2015m12.nc
# 2016
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2016m12.nc
# 2017
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2017m12.nc
# 2018
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2018m12.nc
# 2019
# Check that output is of the correct dimensions:  (12, 192, 288) (12, 192, 288) (12, 192, 288)
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m01.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m02.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m03.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m04.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m05.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m06.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m07.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m08.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m09.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m10.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m11.nc
# saved  /ocean/brogalla/GEOTRACES/data/paper1-forcing-files/atmospheric/atm_flux_y2019m12.nc

# %%
imin, imax = 1480, 2180
jmin, jmax = 160, 800
isize, jsize = imax-imin, jmax-jmin

# %%
print('NCAR dust flux from the atmosphere forcing field -----')
print('Maximum value: ', np.amax(interp_dst_a1[0,imin:imax,jmin:jmax]+interp_dst_a3[0,imin:imax,jmin:jmax]))
print('Minimum value: ', np.amin(interp_dst_a1[0,imin:imax,jmin:jmax]+interp_dst_a3[0,imin:imax,jmin:jmax]))
print('Average value: ', np.average(interp_dst_a1[0,imin:imax,jmin:jmax]+interp_dst_a3[0,imin:imax,jmin:jmax]))
# Out:
# NCAR dust flux from the atmosphere forcing field -----
# Maximum value:  4.793804970368727e-14
# Minimum value:  3.357708424140673e-15
# Average value:  1.0886650673357239e-14
